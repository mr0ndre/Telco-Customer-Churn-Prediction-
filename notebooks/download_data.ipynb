# %%
import os 
import subprocess
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent 
DATA_DIR = PROJECT_ROOT/'data'/'raw'
DATA_NAME = 'yeanzc/telco-customer-churn-ibm-dataset'


DATA_DIR.mkdir(parents=True, exist_ok=True)


print(' ------- Downloading Dataset -------')
print(f'Downloading {DATA_NAME}')

subprocess.run([
    'kaggle',
    'datasets',
    'download',
    '-d',
    DATA_NAME,
    '-p',
    str(DATA_DIR),
    '--unzip'
],
    check=True)

print(' ------- Download complete -------')
# Out:
#  ------- Downloading Dataset -------
# Downloading yeanzc/telco-customer-churn-ibm-dataset
#  ------- Download complete -------
